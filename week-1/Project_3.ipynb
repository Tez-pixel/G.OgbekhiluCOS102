# %%
# Annuity Plan

PAY = float(input("Enter payment each period (PAY): "))
R = float(input("Enter annual interest rate (R %): ")) / 100
n = int(input("Enter number of payments per year (n): "))
t = float(input("Enter number of years (t): "))

A = PMT * (((1 + R / n) * (n * t) - 1) / (R / n))

print("Future Value of Annuity =", A)
